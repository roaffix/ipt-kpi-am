# %% [markdown]
# <h1><center>IAML LAB 4: CLUSTERING, PCA AND EVALUATION</center></h1>

# %%
from scipy.io import arff
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, precision_recall_fscore_support

from IPython.display import HTML

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set(palette = "Set2")

# %%
def update_plot_params():
    params = {'legend.fontsize': 'x-large',
          'figure.figsize': (10, 8),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
    plt.rcParams.update(params)
    
update_plot_params()

# %% [markdown]
# ## CLUSTERING

# %%
data, _ = arff.loadarff('../data/raw/landsat.arff.txt')
landsat = pd.DataFrame(data)

# %%
landsat['class'] = landsat['class'].str.decode('utf-8')

# %%
landsat['class'].value_counts()
# Out:
# 1    1072
# 7    1038
# 3     961
# 2     479
# 5     470
# 4     415
# Name: class, dtype: int64

# %%
Y = landsat.pop('class')
X = landsat

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=0)

# %% [markdown]
# ### K-means

# %%
kmeans = KMeans(n_clusters=6, random_state=0)
kmeans.fit(x_train)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=6, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=0, tol=0.0001, verbose=0)

# %%
kmeans_pred = kmeans.predict(x_test)

# %%
df = pd.DataFrame({'Labels': y_test, 'Clusters': kmeans_pred})
kmeans_conf_matrix = pd.crosstab(df['Labels'], df['Clusters'])

sns.heatmap(kmeans_conf_matrix, annot=True, fmt="d")
plt.ylabel('True label', size=20)
plt.xlabel('Predicted label', size=20)
plt.title('Confusion matrix', size=26)
plt.show()

# %%
noise1 = np.random.normal(0,0.1,df.shape[0])
noise2 = np.random.normal(0,0.1,df.shape[0])
noise = [[x, y] for x, y in zip(noise1, noise2)]

df = df.astype(int)
df = pd.DataFrame(df.values + noise, columns=df.columns, index=df.index)
plt.plot(df['Labels'], df['Clusters'], 'ko')
plt.title('Class against Cluster')
plt.show()

# %% [markdown]
# ### PCA

# %%
pca = PCA(n_components=2).fit(X)
components = pca.transform(X)

# %%
cm = ListedColormap(sns.color_palette("RdYlGn", 30).as_hex())
styles = [
    dict(selector="th", props=[("font-size", "150%"),
                               ("text-align", "center")]),
    dict(selector="caption", props=[("caption-side", "bottom")])
]

# %%
results = (pd.DataFrame(pca.components_,columns=X.columns,index = ['PC1','PC2']).T.style\
        .set_table_styles(styles)
        .background_gradient(cmap=cm))
print('Correlation between a particular pair of component and feature')
display(results)
# Out:
# Correlation between a particular pair of component and feature
# <style  type="text/css" >
#     #T_b38f4434_59d3_11e8_833f_0025904f36cb th {
#           font-size: 150%;
#           text-align: center;
#     }    #T_b38f4434_59d3_11e8_833f_0025904f36cb caption {
#           caption-side: bottom;
#     }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow0_col0 {
#             background-color:  #feda86;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow0_col1 {
#             background-color:  #d42d27;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow1_col0 {
#             background-color:  #108647;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow1_col1 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow2_col0 {
#             background-color:  #fec877;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow2_col1 {
#             background-color:  #8ccd67;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow3_col0 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow3_col1 {
#             background-color:  #108647;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow4_col0 {
#             background-color:  #feda86;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow4_col1 {
#             background-color:  #d42d27;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow5_col0 {
#             background-color:  #108647;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow5_col1 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow6_col0 {
#             background-color:  #fec877;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow6_col1 {
#             background-color:  #8ccd67;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow7_col0 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow7_col1 {
#             background-color:  #108647;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow8_col0 {
#             background-color:  #feda86;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow8_col1 {
#             background-color:  #d42d27;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow9_col0 {
#             background-color:  #18954f;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow9_col1 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow10_col0 {
#             background-color:  #fec877;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow10_col1 {
#             background-color:  #8ccd67;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow11_col0 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow11_col1 {
#             background-color:  #108647;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow12_col0 {
#             background-color:  #feda86;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow12_col1 {
#             background-color:  #d42d27;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow13_col0 {
#             background-color:  #08773f;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow13_col1 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow14_col0 {
#             background-color:  #feda86;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow14_col1 {
#             background-color:  #8ccd67;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow15_col0 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow15_col1 {
#             background-color:  #08773f;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow16_col0 {
#             background-color:  #fee695;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow16_col1 {
#             background-color:  #d42d27;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow17_col0 {
#             background-color:  #08773f;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow17_col1 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow18_col0 {
#             background-color:  #feda86;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow18_col1 {
#             background-color:  #75c465;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow19_col0 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow19_col1 {
#             background-color:  #08773f;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow20_col0 {
#             background-color:  #feda86;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow20_col1 {
#             background-color:  #d42d27;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow21_col0 {
#             background-color:  #08773f;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow21_col1 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow22_col0 {
#             background-color:  #fec877;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow22_col1 {
#             background-color:  #75c465;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow23_col0 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow23_col1 {
#             background-color:  #08773f;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow24_col0 {
#             background-color:  #feda86;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow24_col1 {
#             background-color:  #d42d27;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow25_col0 {
#             background-color:  #108647;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow25_col1 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow26_col0 {
#             background-color:  #fec877;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow26_col1 {
#             background-color:  #8ccd67;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow27_col0 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow27_col1 {
#             background-color:  #108647;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow28_col0 {
#             background-color:  #feda86;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow28_col1 {
#             background-color:  #d42d27;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow29_col0 {
#             background-color:  #108647;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow29_col1 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow30_col0 {
#             background-color:  #fec877;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow30_col1 {
#             background-color:  #8ccd67;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow31_col0 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow31_col1 {
#             background-color:  #08773f;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow32_col0 {
#             background-color:  #feda86;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow32_col1 {
#             background-color:  #d42d27;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow33_col0 {
#             background-color:  #108647;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow33_col1 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow34_col0 {
#             background-color:  #fec877;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow34_col1 {
#             background-color:  #8ccd67;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow35_col0 {
#             background-color:  #b50f26;
#         }    #T_b38f4434_59d3_11e8_833f_0025904f36cbrow35_col1 {
#             background-color:  #108647;
#         }</style>
# <table id="T_b38f4434_59d3_11e8_833f_0025904f36cb" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >PC1</th>
#         <th class="col_heading level0 col1" >PC2</th>

# %%
df = pd.DataFrame(data=components, columns=['PC1', 'PC2'])
df = pd.concat([df, Y], axis=1)

sns.lmplot(x='PC1', y='PC2', data=df, hue='class', fit_reg=False, size=10)
plt.title('PCA components against each other')
plt.show()

# %% [markdown]
# ### Naive Bayes

# %% [markdown]
# Train on PC:

# %%
naive_bayes = GaussianNB()

# %%
scores = cross_validate(naive_bayes, pd.DataFrame(components), Y, 
                        scoring=['accuracy', 'precision_macro', 'recall_macro', 'f1_macro'], 
                        cv=5, return_train_score=True)

# %%
df = pd.DataFrame(scores)
df = df.append(df.mean(axis=0), ignore_index=True)
df.index.name = 'n_folds'
df.index = df.index + 1
df = df.rename(index={6: 'Mean'})

# %%
results = (df.T.style.set_table_styles(styles))
results
# Out:
# <style  type="text/css" >
#     #T_a53cbec8_5926_11e8_833f_0025904f36cb th {
#           font-size: 150%;
#           text-align: center;
#     }    #T_a53cbec8_5926_11e8_833f_0025904f36cb caption {
#           caption-side: bottom;
#     }</style>
# <table id="T_a53cbec8_5926_11e8_833f_0025904f36cb" >
# <thead>    <tr>
#         <th class="index_name level0" >n_folds</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#         <th class="col_heading level0 col4" >5</th>
#         <th class="col_heading level0 col5" >Mean</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a53cbec8_5926_11e8_833f_0025904f36cblevel0_row0" class="row_heading level0 row0" >fit_time</th>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow0_col0" class="data row0 col0" >0.00752783</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow0_col1" class="data row0 col1" >0.00647855</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow0_col2" class="data row0 col2" >0.00642824</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow0_col3" class="data row0 col3" >0.00654674</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow0_col4" class="data row0 col4" >0.00649858</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow0_col5" class="data row0 col5" >0.00669599</td>
#     </tr>    <tr>
#         <th id="T_a53cbec8_5926_11e8_833f_0025904f36cblevel0_row1" class="row_heading level0 row1" >score_time</th>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow1_col0" class="data row1 col0" >0.0111332</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow1_col1" class="data row1 col1" >0.0109103</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow1_col2" class="data row1 col2" >0.0108156</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow1_col3" class="data row1 col3" >0.0110312</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow1_col4" class="data row1 col4" >0.0109832</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow1_col5" class="data row1 col5" >0.0109747</td>
#     </tr>    <tr>
#         <th id="T_a53cbec8_5926_11e8_833f_0025904f36cblevel0_row2" class="row_heading level0 row2" >test_accuracy</th>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow2_col0" class="data row2 col0" >0.84027</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow2_col1" class="data row2 col1" >0.842342</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow2_col2" class="data row2 col2" >0.80947</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow2_col3" class="data row2 col3" >0.698646</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow2_col4" class="data row2 col4" >0.715254</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow2_col5" class="data row2 col5" >0.781196</td>
#     </tr>    <tr>
#         <th id="T_a53cbec8_5926_11e8_833f_0025904f36cblevel0_row3" class="row_heading level0 row3" >test_f1_macro</th>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow3_col0" class="data row3 col0" >0.811767</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow3_col1" class="data row3 col1" >0.816178</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow3_col2" class="data row3 col2" >0.754309</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow3_col3" class="data row3 col3" >0.68141</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow3_col4" class="data row3 col4" >0.674318</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow3_col5" class="data row3 col5" >0.747596</td>
#     </tr>    <tr>
#         <th id="T_a53cbec8_5926_11e8_833f_0025904f36cblevel0_row4" class="row_heading level0 row4" >test_precision_macro</th>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow4_col0" class="data row4 col0" >0.853177</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow4_col1" class="data row4 col1" >0.840857</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow4_col2" class="data row4 col2" >0.768691</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow4_col3" class="data row4 col3" >0.695857</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow4_col4" class="data row4 col4" >0.692243</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow4_col5" class="data row4 col5" >0.770165</td>
#     </tr>    <tr>
#         <th id="T_a53cbec8_5926_11e8_833f_0025904f36cblevel0_row5" class="row_heading level0 row5" >test_recall_macro</th>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow5_col0" class="data row5 col0" >0.797759</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow5_col1" class="data row5 col1" >0.802856</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow5_col2" class="data row5 col2" >0.75332</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow5_col3" class="data row5 col3" >0.679236</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow5_col4" class="data row5 col4" >0.670609</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow5_col5" class="data row5 col5" >0.740756</td>
#     </tr>    <tr>
#         <th id="T_a53cbec8_5926_11e8_833f_0025904f36cblevel0_row6" class="row_heading level0 row6" >train_accuracy</th>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow6_col0" class="data row6 col0" >0.778624</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow6_col1" class="data row6 col1" >0.778404</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow6_col2" class="data row6 col2" >0.775648</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow6_col3" class="data row6 col3" >0.804734</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow6_col4" class="data row6 col4" >0.810141</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow6_col5" class="data row6 col5" >0.78951</td>
#     </tr>    <tr>
#         <th id="T_a53cbec8_5926_11e8_833f_0025904f36cblevel0_row7" class="row_heading level0 row7" >train_f1_macro</th>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow7_col0" class="data row7 col0" >0.739735</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow7_col1" class="data row7 col1" >0.738846</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow7_col2" class="data row7 col2" >0.747299</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow7_col3" class="data row7 col3" >0.771375</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow7_col4" class="data row7 col4" >0.78143</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow7_col5" class="data row7 col5" >0.755737</td>
#     </tr>    <tr>
#         <th id="T_a53cbec8_5926_11e8_833f_0025904f36cblevel0_row8" class="row_heading level0 row8" >train_precision_macro</th>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow8_col0" class="data row8 col0" >0.748084</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow8_col1" class="data row8 col1" >0.752239</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow8_col2" class="data row8 col2" >0.757795</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow8_col3" class="data row8 col3" >0.779879</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow8_col4" class="data row8 col4" >0.788706</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow8_col5" class="data row8 col5" >0.76534</td>
#     </tr>    <tr>
#         <th id="T_a53cbec8_5926_11e8_833f_0025904f36cblevel0_row9" class="row_heading level0 row9" >train_recall_macro</th>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow9_col0" class="data row9 col0" >0.733204</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbrow9_col1" class="data row9 col1" >0.729747</td>
#         <td id="T_a53cbec8_5926_11e8_833f_0025904f36cbro

# %% [markdown]
# Train on original data frame:

# %%
naive_bayes = GaussianNB()

# %%
scores = cross_validate(naive_bayes, X, Y, 
                        scoring=['accuracy', 'precision_macro', 'recall_macro', 'f1_macro'], 
                        cv=5, return_train_score=True)

# %%
df = pd.DataFrame(scores)
df = df.append(df.mean(axis=0), ignore_index=True)
df.index.name = 'n_folds'
df.index = df.index + 1
df = df.rename(index={6: 'Mean'})

# %%
results = (df.T.style.set_table_styles(styles))
results
# Out:
# <style  type="text/css" >
#     #T_a71519a2_5926_11e8_833f_0025904f36cb th {
#           font-size: 150%;
#           text-align: center;
#     }    #T_a71519a2_5926_11e8_833f_0025904f36cb caption {
#           caption-side: bottom;
#     }</style>
# <table id="T_a71519a2_5926_11e8_833f_0025904f36cb" >
# <thead>    <tr>
#         <th class="index_name level0" >n_folds</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#         <th class="col_heading level0 col4" >5</th>
#         <th class="col_heading level0 col5" >Mean</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a71519a2_5926_11e8_833f_0025904f36cblevel0_row0" class="row_heading level0 row0" >fit_time</th>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow0_col0" class="data row0 col0" >0.00901794</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow0_col1" class="data row0 col1" >0.00760889</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow0_col2" class="data row0 col2" >0.00757408</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow0_col3" class="data row0 col3" >0.00756311</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow0_col4" class="data row0 col4" >0.00758481</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow0_col5" class="data row0 col5" >0.00786977</td>
#     </tr>    <tr>
#         <th id="T_a71519a2_5926_11e8_833f_0025904f36cblevel0_row1" class="row_heading level0 row1" >score_time</th>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow1_col0" class="data row1 col0" >0.0156932</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow1_col1" class="data row1 col1" >0.0154736</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow1_col2" class="data row1 col2" >0.0154185</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow1_col3" class="data row1 col3" >0.0154967</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow1_col4" class="data row1 col4" >0.0155697</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow1_col5" class="data row1 col5" >0.0155303</td>
#     </tr>    <tr>
#         <th id="T_a71519a2_5926_11e8_833f_0025904f36cblevel0_row2" class="row_heading level0 row2" >test_accuracy</th>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow2_col0" class="data row2 col0" >0.849269</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow2_col1" class="data row2 col1" >0.829955</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow2_col2" class="data row2 col2" >0.808343</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow2_col3" class="data row2 col3" >0.71219</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow2_col4" class="data row2 col4" >0.700565</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow2_col5" class="data row2 col5" >0.780064</td>
#     </tr>    <tr>
#         <th id="T_a71519a2_5926_11e8_833f_0025904f36cblevel0_row3" class="row_heading level0 row3" >test_f1_macro</th>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow3_col0" class="data row3 col0" >0.834334</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow3_col1" class="data row3 col1" >0.804992</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow3_col2" class="data row3 col2" >0.75417</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow3_col3" class="data row3 col3" >0.706157</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow3_col4" class="data row3 col4" >0.688929</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow3_col5" class="data row3 col5" >0.757716</td>
#     </tr>    <tr>
#         <th id="T_a71519a2_5926_11e8_833f_0025904f36cblevel0_row4" class="row_heading level0 row4" >test_precision_macro</th>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow4_col0" class="data row4 col0" >0.838531</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow4_col1" class="data row4 col1" >0.814177</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow4_col2" class="data row4 col2" >0.769717</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow4_col3" class="data row4 col3" >0.72956</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow4_col4" class="data row4 col4" >0.706107</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow4_col5" class="data row4 col5" >0.771618</td>
#     </tr>    <tr>
#         <th id="T_a71519a2_5926_11e8_833f_0025904f36cblevel0_row5" class="row_heading level0 row5" >test_recall_macro</th>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow5_col0" class="data row5 col0" >0.841401</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow5_col1" class="data row5 col1" >0.801429</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow5_col2" class="data row5 col2" >0.766655</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow5_col3" class="data row5 col3" >0.720545</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow5_col4" class="data row5 col4" >0.70662</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow5_col5" class="data row5 col5" >0.76733</td>
#     </tr>    <tr>
#         <th id="T_a71519a2_5926_11e8_833f_0025904f36cblevel0_row6" class="row_heading level0 row6" >train_accuracy</th>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow6_col0" class="data row6 col0" >0.781444</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow6_col1" class="data row6 col1" >0.789963</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow6_col2" class="data row6 col2" >0.795096</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow6_col3" class="data row6 col3" >0.811496</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow6_col4" class="data row6 col4" >0.814648</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow6_col5" class="data row6 col5" >0.798529</td>
#     </tr>    <tr>
#         <th id="T_a71519a2_5926_11e8_833f_0025904f36cblevel0_row7" class="row_heading level0 row7" >train_f1_macro</th>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow7_col0" class="data row7 col0" >0.760574</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow7_col1" class="data row7 col1" >0.771129</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow7_col2" class="data row7 col2" >0.779235</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow7_col3" class="data row7 col3" >0.789315</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow7_col4" class="data row7 col4" >0.794136</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow7_col5" class="data row7 col5" >0.778878</td>
#     </tr>    <tr>
#         <th id="T_a71519a2_5926_11e8_833f_0025904f36cblevel0_row8" class="row_heading level0 row8" >train_precision_macro</th>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow8_col0" class="data row8 col0" >0.764364</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow8_col1" class="data row8 col1" >0.77497</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow8_col2" class="data row8 col2" >0.781003</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow8_col3" class="data row8 col3" >0.79065</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow8_col4" class="data row8 col4" >0.794794</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow8_col5" class="data row8 col5" >0.781156</td>
#     </tr>    <tr>
#         <th id="T_a71519a2_5926_11e8_833f_0025904f36cblevel0_row9" class="row_heading level0 row9" >train_recall_macro</th>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow9_col0" class="data row9 col0" >0.768661</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbrow9_col1" class="data row9 col1" >0.781389</td>
#         <td id="T_a71519a2_5926_11e8_833f_0025904f36cbro

# %% [markdown]
# ## PERFORMANCE ASSESSMENT #2

# %%
train = pd.read_csv('../data/preprocessed/splice_train.csv')
test = pd.read_csv('../data/preprocessed/splice_test.csv')

# %%
y_train = train.pop('class')
x_train = train
y_test = test.pop('class')
x_test = test

# %% [markdown]
# ###  K-nearest neighbour

# %%
knn_model = KNeighborsClassifier(n_neighbors=1000)
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1000, p=2,
#            weights='uniform')

# %%
knn_pred = knn_model.predict(x_test)

# %%
knn_conf_matrix = confusion_matrix(y_test, knn_pred)
sns.heatmap(knn_conf_matrix, annot=True, fmt="d")
plt.ylabel('True label', size=20)
plt.xlabel('Predicted label', size=20)
plt.title('Confusion matrix', size=26)
plt.show()

# %%
knn_prfs_score = precision_recall_fscore_support(y_test, knn_pred)
knn_df = pd.DataFrame(data={'Precision': knn_prfs_score[0], 'Recall': knn_prfs_score[1], 
                            'F1 score': knn_prfs_score[2], 'Support': knn_prfs_score[3]},
                      columns=['Precision', 'Recall', 'F1 score', 'Support'], index=[0, 1, 2])

results = (knn_df.style.set_table_styles(styles))
results
# Out:
# <style  type="text/css" >
#     #T_ad06d08a_5926_11e8_833f_0025904f36cb th {
#           font-size: 150%;
#           text-align: center;
#     }    #T_ad06d08a_5926_11e8_833f_0025904f36cb caption {
#           caption-side: bottom;
#     }</style>
# <table id="T_ad06d08a_5926_11e8_833f_0025904f36cb" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Precision</th>
#         <th class="col_heading level0 col1" >Recall</th>
#         <th class="col_heading level0 col2" >F1 score</th>
#         <th class="col_heading level0 col3" >Support</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ad06d08a_5926_11e8_833f_0025904f36cblevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_ad06d08a_5926_11e8_833f_0025904f36cbrow0_col0" class="data row0 col0" >0.789474</td>
#         <td id="T_ad06d08a_5926_11e8_833f_0025904f36cbrow0_col1" class="data row0 col1" >0.576923</td>
#         <td id="T_ad06d08a_5926_11e8_833f_0025904f36cbrow0_col2" class="data row0 col2" >0.666667</td>
#         <td id="T_ad06d08a_5926_11e8_833f_0025904f36cbrow0_col3" class="data row0 col3" >52</td>
#     </tr>    <tr>
#         <th id="T_ad06d08a_5926_11e8_833f_0025904f36cblevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_ad06d08a_5926_11e8_833f_0025904f36cbrow1_col0" class="data row1 col0" >1</td>
#         <td id="T_ad06d08a_5926_11e8_833f_0025904f36cbrow1_col1" class="data row1 col1" >0.0555556</td>
#         <td id="T_ad06d08a_5926_11e8_833f_0025904f36cbrow1_col2" class="data row1 col2" >0.105263</td>
#         <td id="T_ad06d08a_5926_11e8_833f_0025904f36cbrow1_col3" class="data row1 col3" >54</td>
#     </tr>    <tr>
#         <th id="T_ad06d08a_5926_11e8_833f_0025904f36cblevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_ad06d08a_5926_11e8_833f_0025904f36cbrow2_col0" class="data row2 col0" >0.672897</td>
#         <td id="T_ad06d08a_5926_11e8_833f_0025904f36cbrow2_col1" class="data row2 col1" >0.966443</td>
#         <td id="T_ad06d08a_5926_11e8_833f_0025904f36cbrow2_col2" class="data row2 col2" >0.793388</td>
#         <td id="T_ad06d08a_5926_11e8_833f_0025904f36cbrow2_col3" class="data row2 col3" >149</td>
#     </tr></tbody>
# </table>
